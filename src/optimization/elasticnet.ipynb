# %%
import numpy as np
import pandas as pd
import warnings
import joblib
import time
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import ElasticNet
import optuna

RANDOM_SEED = 0

warnings.filterwarnings("ignore")
optuna.logging.set_verbosity(optuna.logging.WARNING)
np.random.seed(RANDOM_SEED)

# =============================================================================
# CONFIGURATION
# =============================================================================
print("="*80)
print("ELASTICNET REGRESSION HYPERPARAMETER OPTIMIZATION")
print("="*80)

# =============================================================================
# LOAD PREPROCESSED DATA
# =============================================================================
print("\n" + "="*80)
print("LOADING PREPROCESSED DATA")
print("="*80)

X_train = joblib.load('../../data/preprocessed/X_train.pkl')
y_train = joblib.load('../../data/preprocessed/y_train.pkl')
X_test = joblib.load('../../data/preprocessed/X_test.pkl')
metadata = joblib.load('../../data/preprocessed/metadata.pkl')

print(f"✓ Train shape: {X_train.shape}")
print(f"✓ Target shape: {y_train.shape}")
print(f"✓ Test shape: {X_test.shape}")

# =============================================================================
# OPTIMIZATION SETTINGS
# =============================================================================
FAST_MODE = False  # Set to False for more thorough search
N_TRIALS = 15 if FAST_MODE else 100
N_FOLDS = 5

print(f"\n{'='*60}")
print(f"OPTIMIZATION SETTINGS")
print(f"{'='*60}")
print(f"Mode: {'FAST' if FAST_MODE else 'THOROUGH'}")
print(f"Trials: {N_TRIALS}")
print(f"Folds: {N_FOLDS}")

# =============================================================================
# OBJECTIVE FUNCTION
# =============================================================================
def objective_elasticnet(trial, X, y):
    """Objective function for ElasticNet optimization"""
    
    # Hyperparameters to optimize
    params = {
        'alpha': trial.suggest_float('alpha', 1e-3, 1e2, log=True),
        'l1_ratio': trial.suggest_float('l1_ratio', 0.0, 1.0),
        'fit_intercept': trial.suggest_categorical('fit_intercept', [True, False]),
        'max_iter': trial.suggest_int('max_iter', 1000, 10000),
        'tol': trial.suggest_float('tol', 1e-5, 1e-2, log=True),
        'selection': trial.suggest_categorical('selection', ['cyclic', 'random']),
        'random_state': RANDOM_SEED,
    }

    start_time = time.time()

    print(f"\n{'='*60}")
    print(f"Trial {trial.number}")
    print(f"{'='*60}")
    print(f"Parametri testati: {params}")


    kf = KFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_SEED)
    scores = []

    for fold_idx, (train_idx, val_idx) in enumerate(kf.split(X)):
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        
        # Handle both pandas Series and numpy arrays
        if isinstance(y, pd.Series):
            y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
        else:
            y_tr, y_val = y[train_idx], y[val_idx]

        model = ElasticNet(**params)
        
        try:
            model.fit(X_tr, y_tr)
            preds = np.clip(model.predict(X_val), 0, 100)
            rmse = np.sqrt(mean_squared_error(y_val, preds))
            scores.append(rmse)
        except Exception as e:
            # If model fails to converge, return a high penalty
            return 1e6
        
        print(f"  Fold {fold_idx + 1}: RMSE = {rmse:.4f}")
    
    optimization_time = time.time() - start_time
    mean_score = np.mean(scores)
    print(f"RMSE medio: {mean_score:.4f}")
    print(f"Elapsed Time: {optimization_time:.1f}s")
    print(f"{'='*60}\n")
    
    return mean_score

# =============================================================================
# RUN OPTIMIZATION
# =============================================================================
print("\n" + "="*80)
print("STARTING BAYESIAN OPTIMIZATION")
print("="*80)

start_time = time.time()

study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED)
)

study.optimize(
    lambda trial: objective_elasticnet(trial, X_train, y_train),
    n_trials=N_TRIALS,
    show_progress_bar=True,
    n_jobs=1
)

optimization_time = time.time() - start_time

# =============================================================================
# RESULTS
# =============================================================================
print("\n" + "="*80)
print("OPTIMIZATION RESULTS")
print("="*80)
print(f"Best RMSE: {study.best_value:.6f}")
print(f"Optimization time: {optimization_time:.1f}s")
print(f"\nBest parameters:")
for param, value in sorted(study.best_params.items()):
    print(f"  {param:20s}: {value}")

# =============================================================================
# SAVE RESULTS
# =============================================================================
# Save best parameters
best_params = study.best_params.copy()
best_params['random_state'] = RANDOM_SEED

joblib.dump(best_params, 'elasticnet_params.pkl')
print("\n✓ Parameters saved to: elasticnet_params.pkl")

# Save optimization history
history = pd.DataFrame({
    'trial': [t.number for t in study.trials],
    'value': [t.value for t in study.trials],
    'params': [str(t.params) for t in study.trials]
})
history.to_csv('elasticnet_history.csv', index=False)
print("✓ History saved to: elasticnet_history.csv")

# Save study object
joblib.dump(study, 'elasticnet_study.pkl')
print("✓ Study saved to: elasticnet_study.pkl")

# Save summary
summary = {
    'model': 'ElasticNet',
    'best_rmse': study.best_value,
    'n_trials': N_TRIALS,
    'n_folds': N_FOLDS,
    'optimization_time': optimization_time,
    'best_params': best_params
}
joblib.dump(summary, 'elasticnet_summary.pkl')
print("✓ Summary saved to: elasticnet_summary.pkl")

# =============================================================================
# TRAIN FINAL MODEL ON FULL TRAINING DATA
# =============================================================================
print("\n" + "="*80)
print("TRAINING FINAL MODEL ON FULL DATASET")
print("="*80)

final_model = ElasticNet(**best_params)

print("Training final model...")
final_model.fit(X_train, y_train)

# Save final model
joblib.dump(final_model, 'elasticnet_final_model.pkl')
print("\n✓ Final model saved to: elasticnet_final_model.pkl")

# =============================================================================
# GENERATE PREDICTIONS AND SUBMISSION FILE
# =============================================================================
print("\n" + "="*80)
print("GENERATING PREDICTIONS")
print("="*80)

# Make predictions on test set
test_predictions = final_model.predict(X_test)

# Clip predictions to valid range [0, 100]
test_predictions = np.clip(test_predictions, 0, 100)

# Create submission DataFrame
submission = pd.DataFrame({
    'id': range(len(X_train), len(test_predictions) + len(X_train)),
    'exam_score': test_predictions
})

# Save submission file
submission.to_csv('submission.csv', index=False)
print("✓ Submission file saved to: submission.csv")

print(f"\nSubmission statistics:")
print(f"  Min prediction: {test_predictions.min():.2f}")
print(f"  Max prediction: {test_predictions.max():.2f}")
print(f"  Mean prediction: {test_predictions.mean():.2f}")
print(f"  Median prediction: {np.median(test_predictions):.2f}")
print(f"  Std prediction: {test_predictions.std():.2f}")
print(f"  Shape: {submission.shape}")

# =============================================================================
# FEATURE IMPORTANCE (COEFFICIENTS)
# =============================================================================
print("\n" + "="*80)
print("FEATURE COEFFICIENTS")
print("="*80)

# Get feature coefficients
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'coefficient': final_model.coef_
}).sort_values('coefficient', ascending=False, key=abs)

# Count non-zero coefficients (feature selection)
n_nonzero = (final_model.coef_ != 0).sum()
n_total = len(final_model.coef_)

print(f"\nFeature selection: {n_nonzero}/{n_total} features used ({n_nonzero/n_total*100:.1f}%)")
print("\nTop 10 features by absolute coefficient:")
print(feature_importance.head(10).to_string(index=False))

# Save feature importance
feature_importance.to_csv('elasticnet_coefficients.csv', index=False)
print("\n✓ Coefficients saved to: elasticnet_coefficients.csv")

# =============================================================================
# MODEL STATISTICS
# =============================================================================
print("\n" + "="*80)
print("MODEL STATISTICS")
print("="*80)
print(f"Intercept: {final_model.intercept_:.4f}")
print(f"Alpha (regularization strength): {best_params['alpha']:.6f}")
print(f"L1 ratio: {best_params['l1_ratio']:.4f}")
print(f"  (L1 ratio = 0 → Ridge, L1 ratio = 1 → Lasso)")
print(f"Number of iterations: {final_model.n_iter_}")
print(f"Number of features selected: {n_nonzero}/{n_total}")

# =============================================================================
# FINAL SUMMARY
# =============================================================================
print("\n" + "="*80)
print("ELASTICNET REGRESSION OPTIMIZATION COMPLETE!")
print("="*80)
print(f"✓ Best CV RMSE: {study.best_value:.6f}")
print(f"✓ Final model trained on {len(X_train)} samples")
print(f"✓ Predictions generated for {len(X_test)} test samples")
print(f"✓ All results saved")
print("\nFiles created:")
print("  • elasticnet_params.pkl")
print("  • elasticnet_history.csv")
print("  • elasticnet_study.pkl")
print("  • elasticnet_summary.pkl")
print("  • elasticnet_final_model.pkl")
print("  • elasticnet_coefficients.csv")
print("  • submission.csv")
print("="*80)
# Out:
# ================================================================================
# ELASTICNET REGRESSION HYPERPARAMETER OPTIMIZATION
# ================================================================================
#
# ================================================================================
# LOADING PREPROCESSED DATA
# ================================================================================
# ✓ Train shape: (630000, 8)
# ✓ Target shape: (630000,)
# ✓ Test shape: (270000, 8)
#
# ============================================================
# OPTIMIZATION SETTINGS
# ============================================================
# Mode: THOROUGH
# Trials: 100
# Folds: 5
#
# ================================================================================
# STARTING BAYESIAN OPTIMIZATION
# ================================================================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# ============================================================
# Trial 0
# ============================================================
# Parametri testati: {'alpha': 0.5547119471592125, 'l1_ratio': 0.7151893663724195, 'fit_intercept': True, 'max_iter': 4813, 'tol': 0.0008663279761354553, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8946
#   Fold 2: RMSE = 8.9002
#   Fold 3: RMSE = 8.8716
#   Fold 4: RMSE = 8.9097
#   Fold 5: RMSE = 8.9026
# RMSE medio: 8.8957
# Elapsed Time: 15.7s
# ============================================================
#
#
# ============================================================
# Trial 1
# ============================================================
# Parametri testati: {'alpha': 65.81332043291806, 'l1_ratio': 0.3834415188257777, 'fit_intercept': True, 'max_iter': 6112, 'tol': 0.0059812219011525555, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 9.8627
#   Fold 2: RMSE = 9.8945
#   Fold 3: RMSE = 9.8633
#   Fold 4: RMSE = 9.9156
#   Fold 5: RMSE = 9.9199
# RMSE medio: 9.8912
# Elapsed Time: 1.4s
# ============================================================
#
#
# ============================================================
# Trial 2
# ============================================================
# Parametri testati: {'alpha': 0.0012620948285169307, 'l1_ratio': 0.832619845547938, 'fit_intercept': False, 'max_iter': 9808, 'tol': 0.0024973286104060573, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8992
#   Fold 3: RMSE = 8.8693
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8979
# RMSE medio: 8.8928
# Elapsed Time: 145.8s
# ============================================================
#
#
# ============================================================
# Trial 3
# ============================================================
# Parametri testati: {'alpha': 0.003902762553553294, 'l1_ratio': 0.6399210213275238, 'fit_intercept': False, 'max_iter': 5697, 'tol': 0.00017538232373118029, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8991
#   Fold 3: RMSE = 8.8692
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8978
# RMSE medio: 8.8928
# Elapsed Time: 211.8s
# ============================================================
#
#
# ============================================================
# Trial 4
# ============================================================
# Parametri testati: {'alpha': 0.19087614756145965, 'l1_ratio': 0.5684339488686485, 'fit_intercept': False, 'max_iter': 6509, 'tol': 0.0007092543214735829, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8927
#   Fold 2: RMSE = 8.8990
#   Fold 3: RMSE = 8.8701
#   Fold 4: RMSE = 8.9072
#   Fold 5: RMSE = 8.8995
# RMSE medio: 8.8937
# Elapsed Time: 29.5s
# ============================================================
#
#
# ============================================================
# Trial 5
# ============================================================
# Parametri testati: {'alpha': 0.06273927602293598, 'l1_ratio': 0.43703195379934145, 'fit_intercept': True, 'max_iter': 7001, 'tol': 0.0010278118224157004, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8904
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8921
# Elapsed Time: 52.6s
# ============================================================
#
#
# ============================================================
# Trial 6
# ============================================================
# Parametri testati: {'alpha': 0.03776954513878898, 'l1_ratio': 0.3637107709426226, 'fit_intercept': True, 'max_iter': 9896, 'tol': 2.0236454843648904e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 212.8s
# ============================================================
#
#
# ============================================================
# Trial 7
# ============================================================
# Parametri testati: {'alpha': 1.843069139534017, 'l1_ratio': 0.2532916025397821, 'fit_intercept': True, 'max_iter': 2430, 'tol': 2.143509553579855e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.9023
#   Fold 2: RMSE = 8.9064
#   Fold 3: RMSE = 8.8790
#   Fold 4: RMSE = 8.9174
#   Fold 5: RMSE = 8.9107
# RMSE medio: 8.9032
# Elapsed Time: 5.4s
# ============================================================
#
#
# ============================================================
# Trial 8
# ============================================================
# Parametri testati: {'alpha': 0.009614170248896962, 'l1_ratio': 0.3687251706609641, 'fit_intercept': True, 'max_iter': 8542, 'tol': 1.9422056969726908e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8980
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 31.9s
# ============================================================
#
#
# ============================================================
# Trial 9
# ============================================================
# Parametri testati: {'alpha': 76.5253705047157, 'l1_ratio': 0.604845519745046, 'fit_intercept': True, 'max_iter': 3545, 'tol': 2.293980298131184e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 10.6521
#   Fold 2: RMSE = 10.6902
#   Fold 3: RMSE = 10.6529
#   Fold 4: RMSE = 10.7076
#   Fold 5: RMSE = 10.7143
# RMSE medio: 10.6834
# Elapsed Time: 1.3s
# ============================================================
#
#
# ============================================================
# Trial 10
# ============================================================
# Parametri testati: {'alpha': 6.787264821349604, 'l1_ratio': 0.046050465249730055, 'fit_intercept': False, 'max_iter': 1180, 'tol': 0.00013701892676726144, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.9236
#   Fold 2: RMSE = 8.9276
#   Fold 3: RMSE = 8.9017
#   Fold 4: RMSE = 8.9388
#   Fold 5: RMSE = 8.9338
# RMSE medio: 8.9251
# Elapsed Time: 23.6s
# ============================================================
#
#
# ============================================================
# Trial 11
# ============================================================
# Parametri testati: {'alpha': 0.03629310891656581, 'l1_ratio': 0.21971448188024936, 'fit_intercept': True, 'max_iter': 7737, 'tol': 9.367908981918853e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 159.8s
# ============================================================
#
#
# ============================================================
# Trial 12
# ============================================================
# Parametri testati: {'alpha': 0.027967470616509282, 'l1_ratio': 0.14678149066446766, 'fit_intercept': True, 'max_iter': 9977, 'tol': 6.51435423635438e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 181.4s
# ============================================================
#
#
# ============================================================
# Trial 13
# ============================================================
# Parametri testati: {'alpha': 0.05367533523580092, 'l1_ratio': 0.2257467475334225, 'fit_intercept': True, 'max_iter': 8020, 'tol': 5.137413958713096e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8920
# Elapsed Time: 50.5s
# ============================================================
#
#
# ============================================================
# Trial 14
# ============================================================
# Parametri testati: {'alpha': 0.22893898723883543, 'l1_ratio': 0.007578410233688937, 'fit_intercept': True, 'max_iter': 8646, 'tol': 1.1753473574536959e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8909
#   Fold 2: RMSE = 8.8975
#   Fold 3: RMSE = 8.8684
#   Fold 4: RMSE = 8.9072
#   Fold 5: RMSE = 8.8983
# RMSE medio: 8.8925
# Elapsed Time: 49.6s
# ============================================================
#
#
# ============================================================
# Trial 15
# ============================================================
# Parametri testati: {'alpha': 0.010518265506947325, 'l1_ratio': 0.3144863069517587, 'fit_intercept': True, 'max_iter': 8541, 'tol': 5.184338347110417e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8980
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 39.3s
# ============================================================
#
#
# ============================================================
# Trial 16
# ============================================================
# Parametri testati: {'alpha': 1.8325321115935844, 'l1_ratio': 0.988166412193483, 'fit_intercept': True, 'max_iter': 7550, 'tol': 0.00030362340943985397, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8965
#   Fold 2: RMSE = 8.9031
#   Fold 3: RMSE = 8.8747
#   Fold 4: RMSE = 8.9132
#   Fold 5: RMSE = 8.9064
# RMSE medio: 8.8988
# Elapsed Time: 1.2s
# ============================================================
#
#
# ============================================================
# Trial 17
# ============================================================
# Parametri testati: {'alpha': 0.09741192881970875, 'l1_ratio': 0.14358871736454482, 'fit_intercept': True, 'max_iter': 9282, 'tol': 4.034182636804165e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8904
#   Fold 2: RMSE = 8.8975
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8977
# RMSE medio: 8.8921
# Elapsed Time: 25.4s
# ============================================================
#
#
# ============================================================
# Trial 18
# ============================================================
# Parametri testati: {'alpha': 0.0010155515538125103, 'l1_ratio': 0.4659094479943382, 'fit_intercept': False, 'max_iter': 4461, 'tol': 1.180283651937424e-05, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8992
#   Fold 3: RMSE = 8.8693
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8979
# RMSE medio: 8.8928
# Elapsed Time: 133.5s
# ============================================================
#
#
# ============================================================
# Trial 19
# ============================================================
# Parametri testati: {'alpha': 0.5472954908908619, 'l1_ratio': 0.1758784914797005, 'fit_intercept': True, 'max_iter': 7805, 'tol': 3.6638449257356675e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8927
#   Fold 2: RMSE = 8.8983
#   Fold 3: RMSE = 8.8698
#   Fold 4: RMSE = 8.9081
#   Fold 5: RMSE = 8.9002
# RMSE medio: 8.8938
# Elapsed Time: 11.5s
# ============================================================
#
#
# ============================================================
# Trial 20
# ============================================================
# Parametri testati: {'alpha': 0.013672698224722507, 'l1_ratio': 0.30638102439346476, 'fit_intercept': True, 'max_iter': 9219, 'tol': 0.0002834752663677542, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 31.8s
# ============================================================
#
#
# ============================================================
# Trial 21
# ============================================================
# Parametri testati: {'alpha': 0.0562540849753176, 'l1_ratio': 0.21782269939785529, 'fit_intercept': True, 'max_iter': 7977, 'tol': 9.457904142244362e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8920
# Elapsed Time: 46.0s
# ============================================================
#
#
# ============================================================
# Trial 22
# ============================================================
# Parametri testati: {'alpha': 0.08159292389400362, 'l1_ratio': 0.08911479519492987, 'fit_intercept': True, 'max_iter': 7015, 'tol': 9.455413643130992e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9067
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8921
# Elapsed Time: 144.5s
# ============================================================
#
#
# ============================================================
# Trial 23
# ============================================================
# Parametri testati: {'alpha': 0.004403428664937459, 'l1_ratio': 0.26952135777440217, 'fit_intercept': True, 'max_iter': 8179, 'tol': 3.1175796872082276e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8981
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9067
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 215.7s
# ============================================================
#
#
# ============================================================
# Trial 24
# ============================================================
# Parametri testati: {'alpha': 0.0358007806338945, 'l1_ratio': 0.3739436453581483, 'fit_intercept': True, 'max_iter': 9201, 'tol': 0.00018156891604979503, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 67.7s
# ============================================================
#
#
# ============================================================
# Trial 25
# ============================================================
# Parametri testati: {'alpha': 0.026123402759759648, 'l1_ratio': 0.5033293523824509, 'fit_intercept': True, 'max_iter': 9232, 'tol': 0.0005301437722731738, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 14.9s
# ============================================================
#
#
# ============================================================
# Trial 26
# ============================================================
# Parametri testati: {'alpha': 0.003217224361331621, 'l1_ratio': 0.558035342698879, 'fit_intercept': False, 'max_iter': 9191, 'tol': 0.0005794870437355049, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8991
#   Fold 3: RMSE = 8.8693
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8978
# RMSE medio: 8.8928
# Elapsed Time: 348.7s
# ============================================================
#
#
# ============================================================
# Trial 27
# ============================================================
# Parametri testati: {'alpha': 0.017629731609015254, 'l1_ratio': 0.48271244398436425, 'fit_intercept': True, 'max_iter': 10000, 'tol': 0.001758676704351819, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 17.4s
# ============================================================
#
#
# ============================================================
# Trial 28
# ============================================================
# Parametri testati: {'alpha': 0.14404564251657867, 'l1_ratio': 0.7119896247751584, 'fit_intercept': True, 'max_iter': 9051, 'tol': 0.007763455233389656, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8913
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8684
#   Fold 4: RMSE = 8.9069
#   Fold 5: RMSE = 8.8981
# RMSE medio: 8.8925
# Elapsed Time: 1.4s
# ============================================================
#
#
# ============================================================
# Trial 29
# ============================================================
# Parametri testati: {'alpha': 0.7154119398733432, 'l1_ratio': 0.39399912596816006, 'fit_intercept': True, 'max_iter': 5156, 'tol': 0.00044808006857481586, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8954
#   Fold 2: RMSE = 8.9003
#   Fold 3: RMSE = 8.8722
#   Fold 4: RMSE = 8.9102
#   Fold 5: RMSE = 8.9032
# RMSE medio: 8.8963
# Elapsed Time: 14.9s
# ============================================================
#
#
# ============================================================
# Trial 30
# ============================================================
# Parametri testati: {'alpha': 0.44026681082698327, 'l1_ratio': 0.5306885193530466, 'fit_intercept': True, 'max_iter': 3840, 'tol': 0.0011818748798978099, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8934
#   Fold 2: RMSE = 8.8991
#   Fold 3: RMSE = 8.8703
#   Fold 4: RMSE = 8.9082
#   Fold 5: RMSE = 8.9010
# RMSE medio: 8.8944
# Elapsed Time: 1.5s
# ============================================================
#
#
# ============================================================
# Trial 31
# ============================================================
# Parametri testati: {'alpha': 0.02300292933308894, 'l1_ratio': 0.34228340158040677, 'fit_intercept': True, 'max_iter': 9464, 'tol': 0.00019836004582069716, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 21.7s
# ============================================================
#
#
# ============================================================
# Trial 32
# ============================================================
# Parametri testati: {'alpha': 0.041406283645483884, 'l1_ratio': 0.4303365301026971, 'fit_intercept': True, 'max_iter': 8697, 'tol': 0.0004625197243462726, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 11.2s
# ============================================================
#
#
# ============================================================
# Trial 33
# ============================================================
# Parametri testati: {'alpha': 0.006893964282608066, 'l1_ratio': 0.42034539436650237, 'fit_intercept': True, 'max_iter': 8793, 'tol': 0.0005187661287923822, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8980
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 49.3s
# ============================================================
#
#
# ============================================================
# Trial 34
# ============================================================
# Parametri testati: {'alpha': 0.002174009943554779, 'l1_ratio': 0.6634191026541808, 'fit_intercept': True, 'max_iter': 9480, 'tol': 0.0030806422548177994, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8980
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9067
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 353.5s
# ============================================================
#
#
# ============================================================
# Trial 35
# ============================================================
# Parametri testati: {'alpha': 25.330363290049434, 'l1_ratio': 0.7879572761470881, 'fit_intercept': False, 'max_iter': 6084, 'tol': 0.0036228025237188526, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.9422
#   Fold 2: RMSE = 8.9444
#   Fold 3: RMSE = 8.9192
#   Fold 4: RMSE = 8.9537
#   Fold 5: RMSE = 8.9496
# RMSE medio: 8.9418
# Elapsed Time: 0.9s
# ============================================================
#
#
# ============================================================
# Trial 36
# ============================================================
# Parametri testati: {'alpha': 0.03345485323365153, 'l1_ratio': 0.49980390722239143, 'fit_intercept': True, 'max_iter': 9775, 'tol': 0.0017898390540049402, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 215.3s
# ============================================================
#
#
# ============================================================
# Trial 37
# ============================================================
# Parametri testati: {'alpha': 0.14049710044283736, 'l1_ratio': 0.4310178600019111, 'fit_intercept': False, 'max_iter': 7118, 'tol': 0.0015977340619656984, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8935
#   Fold 2: RMSE = 8.8995
#   Fold 3: RMSE = 8.8710
#   Fold 4: RMSE = 8.9082
#   Fold 5: RMSE = 8.9001
# RMSE medio: 8.8945
# Elapsed Time: 263.3s
# ============================================================
#
#
# ============================================================
# Trial 38
# ============================================================
# Parametri testati: {'alpha': 0.0068400128907082115, 'l1_ratio': 0.36834377709093025, 'fit_intercept': True, 'max_iter': 9709, 'tol': 0.0010830194376889382, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 371.3s
# ============================================================
#
#
# ============================================================
# Trial 39
# ============================================================
# Parametri testati: {'alpha': 0.29429514951439223, 'l1_ratio': 0.6021348648440471, 'fit_intercept': True, 'max_iter': 8472, 'tol': 0.00019848173762234894, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8923
#   Fold 2: RMSE = 8.8982
#   Fold 3: RMSE = 8.8694
#   Fold 4: RMSE = 8.9075
#   Fold 5: RMSE = 8.8998
# RMSE medio: 8.8934
# Elapsed Time: 23.0s
# ============================================================
#
#
# ============================================================
# Trial 40
# ============================================================
# Parametri testati: {'alpha': 1.1076883033387794, 'l1_ratio': 0.4708113313756685, 'fit_intercept': True, 'max_iter': 6495, 'tol': 0.006390528966170971, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.9007
#   Fold 2: RMSE = 8.9047
#   Fold 3: RMSE = 8.8771
#   Fold 4: RMSE = 8.9153
#   Fold 5: RMSE = 8.9084
# RMSE medio: 8.9012
# Elapsed Time: 9.5s
# ============================================================
#
#
# ============================================================
# Trial 41
# ============================================================
# Parametri testati: {'alpha': 0.035615540218993734, 'l1_ratio': 0.5298711960174489, 'fit_intercept': True, 'max_iter': 9595, 'tol': 0.00035766919009506346, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 209.6s
# ============================================================
#
#
# ============================================================
# Trial 42
# ============================================================
# Parametri testati: {'alpha': 0.04645952243669937, 'l1_ratio': 0.5286762834189718, 'fit_intercept': True, 'max_iter': 9734, 'tol': 0.0008446448118969264, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8920
# Elapsed Time: 174.1s
# ============================================================
#
#
# ============================================================
# Trial 43
# ============================================================
# Parametri testati: {'alpha': 0.12648886783800017, 'l1_ratio': 0.5867799046175524, 'fit_intercept': True, 'max_iter': 8895, 'tol': 0.0003881507777789862, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8911
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8686
#   Fold 4: RMSE = 8.9069
#   Fold 5: RMSE = 8.8984
# RMSE medio: 8.8925
# Elapsed Time: 47.2s
# ============================================================
#
#
# ============================================================
# Trial 44
# ============================================================
# Parametri testati: {'alpha': 0.034509059154391036, 'l1_ratio': 0.6537835581214027, 'fit_intercept': True, 'max_iter': 9986, 'tol': 0.0020502018300872092, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 207.7s
# ============================================================
#
#
# ============================================================
# Trial 45
# ============================================================
# Parametri testati: {'alpha': 0.0163785512811438, 'l1_ratio': 0.40300332905625325, 'fit_intercept': True, 'max_iter': 8331, 'tol': 0.004516367815839744, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 324.7s
# ============================================================
#
#
# ============================================================
# Trial 46
# ============================================================
# Parametri testati: {'alpha': 0.07780219091413103, 'l1_ratio': 0.3098001232234886, 'fit_intercept': False, 'max_iter': 7385, 'tol': 0.0006456338970149719, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8926
#   Fold 2: RMSE = 8.8991
#   Fold 3: RMSE = 8.8703
#   Fold 4: RMSE = 8.9076
#   Fold 5: RMSE = 8.8992
# RMSE medio: 8.8938
# Elapsed Time: 268.4s
# ============================================================
#
#
# ============================================================
# Trial 47
# ============================================================
# Parametri testati: {'alpha': 0.008100187087547131, 'l1_ratio': 0.4433177043087422, 'fit_intercept': True, 'max_iter': 9547, 'tol': 0.00013544083594620746, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 295.0s
# ============================================================
#
#
# ============================================================
# Trial 48
# ============================================================
# Parametri testati: {'alpha': 0.04108709179580775, 'l1_ratio': 0.3492278716332104, 'fit_intercept': True, 'max_iter': 8849, 'tol': 0.0002874254531748251, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 199.4s
# ============================================================
#
#
# ============================================================
# Trial 49
# ============================================================
# Parametri testati: {'alpha': 0.22241834126725948, 'l1_ratio': 0.5381321987274341, 'fit_intercept': True, 'max_iter': 1610, 'tol': 0.00013800257732255646, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8915
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8689
#   Fold 4: RMSE = 8.9070
#   Fold 5: RMSE = 8.8990
# RMSE medio: 8.8929
# Elapsed Time: 3.3s
# ============================================================
#
#
# ============================================================
# Trial 50
# ============================================================
# Parametri testati: {'alpha': 0.012914263818445565, 'l1_ratio': 0.7379145454427454, 'fit_intercept': True, 'max_iter': 9568, 'tol': 1.6964007272613652e-05, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 20.8s
# ============================================================
#
#
# ============================================================
# Trial 51
# ============================================================
# Parametri testati: {'alpha': 0.028696992062238923, 'l1_ratio': 0.6910648707370737, 'fit_intercept': True, 'max_iter': 9914, 'tol': 0.0021379389456557376, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 251.6s
# ============================================================
#
#
# ============================================================
# Trial 52
# ============================================================
# Parametri testati: {'alpha': 0.022962611313848757, 'l1_ratio': 0.8793004644449401, 'fit_intercept': True, 'max_iter': 8906, 'tol': 0.0013979054375390966, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 264.2s
# ============================================================
#
#
# ============================================================
# Trial 53
# ============================================================
# Parametri testati: {'alpha': 0.02315088756448162, 'l1_ratio': 0.9589756775407713, 'fit_intercept': True, 'max_iter': 8652, 'tol': 0.0013741056583958557, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 264.1s
# ============================================================
#
#
# ============================================================
# Trial 54
# ============================================================
# Parametri testati: {'alpha': 0.0047361508502615605, 'l1_ratio': 0.9285675805985635, 'fit_intercept': True, 'max_iter': 8606, 'tol': 0.0013119043831440365, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8980
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 326.0s
# ============================================================
#
#
# ============================================================
# Trial 55
# ============================================================
# Parametri testati: {'alpha': 0.06393954148861551, 'l1_ratio': 0.8882994773920425, 'fit_intercept': True, 'max_iter': 8268, 'tol': 0.002532349050583819, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8908
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8684
#   Fold 4: RMSE = 8.9067
#   Fold 5: RMSE = 8.8980
# RMSE medio: 8.8923
# Elapsed Time: 94.4s
# ============================================================
#
#
# ============================================================
# Trial 56
# ============================================================
# Parametri testati: {'alpha': 0.019110067479486455, 'l1_ratio': 0.9819210963831705, 'fit_intercept': True, 'max_iter': 7658, 'tol': 0.0007501306742573184, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 257.5s
# ============================================================
#
#
# ============================================================
# Trial 57
# ============================================================
# Parametri testati: {'alpha': 0.002033390083061191, 'l1_ratio': 0.8286577046772726, 'fit_intercept': False, 'max_iter': 8916, 'tol': 0.00039209634963351776, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8991
#   Fold 3: RMSE = 8.8693
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8979
# RMSE medio: 8.8928
# Elapsed Time: 354.7s
# ============================================================
#
#
# ============================================================
# Trial 58
# ============================================================
# Parametri testati: {'alpha': 0.09848704060995797, 'l1_ratio': 0.9367296967485205, 'fit_intercept': True, 'max_iter': 8028, 'tol': 0.0009513155727178545, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8911
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8686
#   Fold 4: RMSE = 8.9068
#   Fold 5: RMSE = 8.8985
# RMSE medio: 8.8925
# Elapsed Time: 53.5s
# ============================================================
#
#
# ============================================================
# Trial 59
# ============================================================
# Parametri testati: {'alpha': 0.012278375597299482, 'l1_ratio': 0.8496560744285014, 'fit_intercept': True, 'max_iter': 9392, 'tol': 0.00024159652826421255, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 301.0s
# ============================================================
#
#
# ============================================================
# Trial 60
# ============================================================
# Parametri testati: {'alpha': 0.023558163655147513, 'l1_ratio': 0.7572586083563464, 'fit_intercept': True, 'max_iter': 7334, 'tol': 0.0024136259010256035, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 261.4s
# ============================================================
#
#
# ============================================================
# Trial 61
# ============================================================
# Parametri testati: {'alpha': 0.023600553439631994, 'l1_ratio': 0.7628587528737412, 'fit_intercept': True, 'max_iter': 6636, 'tol': 0.0014060287381270405, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 242.8s
# ============================================================
#
#
# ============================================================
# Trial 62
# ============================================================
# Parametri testati: {'alpha': 0.053176972443504354, 'l1_ratio': 0.8138861916114517, 'fit_intercept': True, 'max_iter': 8545, 'tol': 0.002384169845012713, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8905
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8978
# RMSE medio: 8.8921
# Elapsed Time: 116.1s
# ============================================================
#
#
# ============================================================
# Trial 63
# ============================================================
# Parametri testati: {'alpha': 0.009976878042198793, 'l1_ratio': 0.8719947428337703, 'fit_intercept': True, 'max_iter': 9075, 'tol': 0.004566725230774895, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 362.4s
# ============================================================
#
#
# ============================================================
# Trial 64
# ============================================================
# Parametri testati: {'alpha': 0.020509758725793713, 'l1_ratio': 0.6964409676263046, 'fit_intercept': True, 'max_iter': 7258, 'tol': 0.0030793021843268406, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 286.6s
# ============================================================
#
#
# ============================================================
# Trial 65
# ============================================================
# Parametri testati: {'alpha': 0.006097886993822967, 'l1_ratio': 0.6317976604174204, 'fit_intercept': True, 'max_iter': 7837, 'tol': 0.0008486143874568077, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9067
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 322.7s
# ============================================================
#
#
# ============================================================
# Trial 66
# ============================================================
# Parametri testati: {'alpha': 0.029753730800084786, 'l1_ratio': 0.9497603448583839, 'fit_intercept': True, 'max_iter': 9987, 'tol': 0.0021460150492597875, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8904
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 212.1s
# ============================================================
#
#
# ============================================================
# Trial 67
# ============================================================
# Parametri testati: {'alpha': 0.07332048407338518, 'l1_ratio': 0.9067404185076197, 'fit_intercept': True, 'max_iter': 5627, 'tol': 0.00960393556164401, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8910
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8685
#   Fold 4: RMSE = 8.9069
#   Fold 5: RMSE = 8.8983
# RMSE medio: 8.8925
# Elapsed Time: 80.9s
# ============================================================
#
#
# ============================================================
# Trial 68
# ============================================================
# Parametri testati: {'alpha': 0.015456438069412468, 'l1_ratio': 0.7849618087294444, 'fit_intercept': True, 'max_iter': 8727, 'tol': 6.915681870757474e-05, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 254.1s
# ============================================================
#
#
# ============================================================
# Trial 69
# ============================================================
# Parametri testati: {'alpha': 0.0029263157225774485, 'l1_ratio': 0.8616618862633748, 'fit_intercept': False, 'max_iter': 9217, 'tol': 0.004558448740074477, 'selection': 'cyclic', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8991
#   Fold 3: RMSE = 8.8693
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8979
# RMSE medio: 8.8928
# Elapsed Time: 11.1s
# ============================================================
#
#
# ============================================================
# Trial 70
# ============================================================
# Parametri testati: {'alpha': 0.04860248945094676, 'l1_ratio': 0.68603202181898, 'fit_intercept': True, 'max_iter': 8166, 'tol': 0.0015148029017526606, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8904
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8921
# Elapsed Time: 137.3s
# ============================================================
#
#
# ============================================================
# Trial 71
# ============================================================
# Parametri testati: {'alpha': 0.03119901033708548, 'l1_ratio': 0.744349724058907, 'fit_intercept': True, 'max_iter': 6720, 'tol': 0.001463139572980746, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 226.7s
# ============================================================
#
#
# ============================================================
# Trial 72
# ============================================================
# Parametri testati: {'alpha': 0.027020755820791702, 'l1_ratio': 0.7440852838755467, 'fit_intercept': True, 'max_iter': 6799, 'tol': 0.0028704759830673597, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 263.2s
# ============================================================
#
#
# ============================================================
# Trial 73
# ============================================================
# Parametri testati: {'alpha': 0.02856456759637005, 'l1_ratio': 0.7705370839253123, 'fit_intercept': True, 'max_iter': 6207, 'tol': 0.002959934943506361, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 219.0s
# ============================================================
#
#
# ============================================================
# Trial 74
# ============================================================
# Parametri testati: {'alpha': 0.10910622396052037, 'l1_ratio': 0.7902819899670378, 'fit_intercept': True, 'max_iter': 5270, 'tol': 0.003017640684163371, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8911
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8686
#   Fold 4: RMSE = 8.9069
#   Fold 5: RMSE = 8.8985
# RMSE medio: 8.8926
# Elapsed Time: 62.2s
# ============================================================
#
#
# ============================================================
# Trial 75
# ============================================================
# Parametri testati: {'alpha': 0.011127813872792464, 'l1_ratio': 0.7406232726051931, 'fit_intercept': True, 'max_iter': 6124, 'tol': 0.0036568814970908015, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 236.0s
# ============================================================
#
#
# ============================================================
# Trial 76
# ============================================================
# Parametri testati: {'alpha': 0.023191751079085797, 'l1_ratio': 0.8157727053389718, 'fit_intercept': True, 'max_iter': 6028, 'tol': 0.002649717888607269, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 241.3s
# ============================================================
#
#
# ============================================================
# Trial 77
# ============================================================
# Parametri testati: {'alpha': 7.361999782607939, 'l1_ratio': 0.9051928565378189, 'fit_intercept': True, 'max_iter': 6896, 'tol': 0.0018998820527848397, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.9577
#   Fold 2: RMSE = 8.9666
#   Fold 3: RMSE = 8.9402
#   Fold 4: RMSE = 8.9809
#   Fold 5: RMSE = 8.9766
# RMSE medio: 8.9644
# Elapsed Time: 3.2s
# ============================================================
#
#
# ============================================================
# Trial 78
# ============================================================
# Parametri testati: {'alpha': 0.04074574712143268, 'l1_ratio': 0.9604460691129975, 'fit_intercept': True, 'max_iter': 6339, 'tol': 0.005374744310418481, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8905
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8977
# RMSE medio: 8.8921
# Elapsed Time: 150.3s
# ============================================================
#
#
# ============================================================
# Trial 79
# ============================================================
# Parametri testati: {'alpha': 0.015962738427075424, 'l1_ratio': 0.6823621234068893, 'fit_intercept': True, 'max_iter': 5964, 'tol': 0.0036136982104347255, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 237.6s
# ============================================================
#
#
# ============================================================
# Trial 80
# ============================================================
# Parametri testati: {'alpha': 0.17384565201375532, 'l1_ratio': 0.6222574297259641, 'fit_intercept': True, 'max_iter': 7503, 'tol': 0.0011301764648237382, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8914
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8687
#   Fold 4: RMSE = 8.9070
#   Fold 5: RMSE = 8.8988
# RMSE medio: 8.8927
# Elapsed Time: 40.8s
# ============================================================
#
#
# ============================================================
# Trial 81
# ============================================================
# Parametri testati: {'alpha': 0.02837861893092068, 'l1_ratio': 0.7342235596877258, 'fit_intercept': True, 'max_iter': 6586, 'tol': 0.0012636534082749956, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 208.3s
# ============================================================
#
#
# ============================================================
# Trial 82
# ============================================================
# Parametri testati: {'alpha': 0.008878853184688017, 'l1_ratio': 0.765424775462963, 'fit_intercept': True, 'max_iter': 6890, 'tol': 0.0017415113827107145, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 248.1s
# ============================================================
#
#
# ============================================================
# Trial 83
# ============================================================
# Parametri testati: {'alpha': 0.06683345423233158, 'l1_ratio': 0.7303781466855674, 'fit_intercept': True, 'max_iter': 7187, 'tol': 0.0006783589235477055, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8906
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8683
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8979
# RMSE medio: 8.8922
# Elapsed Time: 74.3s
# ============================================================
#
#
# ============================================================
# Trial 84
# ============================================================
# Parametri testati: {'alpha': 0.028443993309361492, 'l1_ratio': 0.8426471873838337, 'fit_intercept': True, 'max_iter': 4773, 'tol': 0.0012626292891354466, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8904
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 155.9s
# ============================================================
#
#
# ============================================================
# Trial 85
# ============================================================
# Parametri testati: {'alpha': 0.043767219975527814, 'l1_ratio': 0.7178136287315412, 'fit_intercept': True, 'max_iter': 6316, 'tol': 0.0021978308884835923, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8904
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8976
# RMSE medio: 8.8921
# Elapsed Time: 382.8s
# ============================================================
#
#
# ============================================================
# Trial 86
# ============================================================
# Parametri testati: {'alpha': 0.02113813713259016, 'l1_ratio': 0.7639610757522705, 'fit_intercept': True, 'max_iter': 6449, 'tol': 0.0026576739616588434, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 1002.4s
# ============================================================
#
#
# ============================================================
# Trial 87
# ============================================================
# Parametri testati: {'alpha': 0.01456437096649798, 'l1_ratio': 0.6685670093820059, 'fit_intercept': False, 'max_iter': 5460, 'tol': 0.0003689708982154279, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8912
#   Fold 2: RMSE = 8.8988
#   Fold 3: RMSE = 8.8692
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8978
# RMSE medio: 8.8927
# Elapsed Time: 584.4s
# ============================================================
#
#
# ============================================================
# Trial 88
# ============================================================
# Parametri testati: {'alpha': 0.005367426270669582, 'l1_ratio': 0.5685068464361526, 'fit_intercept': True, 'max_iter': 9670, 'tol': 0.0004989136747743675, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 1205.6s
# ============================================================
#
#
# ============================================================
# Trial 89
# ============================================================
# Parametri testati: {'alpha': 0.09140810238977817, 'l1_ratio': 0.8058038795586487, 'fit_intercept': True, 'max_iter': 7827, 'tol': 0.0009915667782484647, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8910
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8685
#   Fold 4: RMSE = 8.9068
#   Fold 5: RMSE = 8.8983
# RMSE medio: 8.8925
# Elapsed Time: 109.4s
# ============================================================
#
#
# ============================================================
# Trial 90
# ============================================================
# Parametri testati: {'alpha': 0.007512915929483679, 'l1_ratio': 0.6980682140694661, 'fit_intercept': True, 'max_iter': 8399, 'tol': 0.0038911647407135616, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9066
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 592.1s
# ============================================================
#
#
# ============================================================
# Trial 91
# ============================================================
# Parametri testati: {'alpha': 0.03084956892129557, 'l1_ratio': 0.7505655657590343, 'fit_intercept': True, 'max_iter': 6664, 'tol': 0.0016436121778972423, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 402.5s
# ============================================================
#
#
# ============================================================
# Trial 92
# ============================================================
# Parametri testati: {'alpha': 0.05711505042027281, 'l1_ratio': 0.7138340409430954, 'fit_intercept': True, 'max_iter': 6919, 'tol': 0.001628859420826929, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8905
#   Fold 2: RMSE = 8.8976
#   Fold 3: RMSE = 8.8682
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8977
# RMSE medio: 8.8921
# Elapsed Time: 219.8s
# ============================================================
#
#
# ============================================================
# Trial 93
# ============================================================
# Parametri testati: {'alpha': 0.0284488290058105, 'l1_ratio': 0.8892253030989603, 'fit_intercept': True, 'max_iter': 5743, 'tol': 0.0019815591318315218, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 393.3s
# ============================================================
#
#
# ============================================================
# Trial 94
# ============================================================
# Parametri testati: {'alpha': 0.018308227040816933, 'l1_ratio': 0.7896792114066612, 'fit_intercept': True, 'max_iter': 6669, 'tol': 0.005707992064328307, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8978
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 560.9s
# ============================================================
#
#
# ============================================================
# Trial 95
# ============================================================
# Parametri testati: {'alpha': 0.03420827433158002, 'l1_ratio': 0.6570865308990531, 'fit_intercept': True, 'max_iter': 7377, 'tol': 0.0029175492819488082, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 246.8s
# ============================================================
#
#
# ============================================================
# Trial 96
# ============================================================
# Parametri testati: {'alpha': 0.024433329844848858, 'l1_ratio': 0.9814980475038658, 'fit_intercept': True, 'max_iter': 9417, 'tol': 0.0007919810910780494, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 274.9s
# ============================================================
#
#
# ============================================================
# Trial 97
# ============================================================
# Parametri testati: {'alpha': 0.011941143158952207, 'l1_ratio': 0.924585839793292, 'fit_intercept': True, 'max_iter': 9076, 'tol': 0.0007624226895233565, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8979
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9065
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8921
# Elapsed Time: 451.4s
# ============================================================
#
#
# ============================================================
# Trial 98
# ============================================================
# Parametri testati: {'alpha': 0.02250809506706705, 'l1_ratio': 0.9790431919124423, 'fit_intercept': True, 'max_iter': 9383, 'tol': 0.0005999978115360325, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 249.2s
# ============================================================
#
#
# ============================================================
# Trial 99
# ============================================================
# Parametri testati: {'alpha': 0.02324818142965521, 'l1_ratio': 0.9874189228290325, 'fit_intercept': True, 'max_iter': 9456, 'tol': 0.0010226691831117097, 'selection': 'random', 'random_state': 0}
#   Fold 1: RMSE = 8.8903
#   Fold 2: RMSE = 8.8977
#   Fold 3: RMSE = 8.8681
#   Fold 4: RMSE = 8.9064
#   Fold 5: RMSE = 8.8975
# RMSE medio: 8.8920
# Elapsed Time: 410.8s
# ============================================================
#
#
# ================================================================================
# OPTIMIZATION RESULTS
# ================================================================================
# Best RMSE: 8.892010
# Optimization time: 19273.0s
#
# Best parameters:
#   alpha               : 0.027020755820791702
#   fit_intercept       : True
#   l1_ratio            : 0.7440852838755467
#   max_iter            : 6799
#   selection           : random
#   tol                 : 0.0028704759830673597
#
# ✓ Parameters saved to: elasticnet_params.pkl
# ✓ History saved to: elasticnet_history.csv
# ✓ Study saved to: elasticnet_study.pkl
# ✓ Summary saved to: elasticnet_summary.pkl
#
# ================================================================================
# TRAINING FINAL MODEL ON FULL DATASET
# ================================================================================
# Training final model...
#
# ✓ Final model saved to: elasticnet_final_model.pkl
#
# ================================================================================
# GENERATING PREDICTIONS
# ================================================================================
# ✓ Submission file saved to: submission.csv
#
# Submission statistics:
#   Min prediction: 15.18
#   Max prediction: 100.00
#   Mean prediction: 62.51
#   Median prediction: 62.74
#   Std prediction: 16.66
#   Shape: (270000, 2)
#
# ================================================================================
# FEATURE COEFFICIENTS
# ================================================================================
#
# Feature selection: 7/8 features used (87.5%)
#
# Top 10 features by absolute coefficient:
#                 feature  coefficient
#                 formula     0.911919
#             study_hours     0.255556
#      study_from_optimal    -0.126278
#             sleep_hours    -0.028749
#        class_attendance    -0.015343
# attendance_from_optimal    -0.011397
#         formula_x_study    -0.001593
#        formula_residual     0.000000
#
# ✓ Coefficients saved to: elasticnet_coefficients.csv
#
# ================================================================================
# MODEL STATISTICS
# ================================================================================
# Intercept: 6.0203
# Alpha (regularization strength): 0.027021
# L1 ratio: 0.7441
#   (L1 ratio = 0 → Ridge, L1 ratio = 1 → Lasso)
# Number of iterations: 6787
# Number of features selected: 7/8
#
# ================================================================================
# ELASTICNET REGRESSION OPTIMIZATION COMPLETE!
# ================================================================================
# ✓ Best CV RMSE: 8.892010
# ✓ Final model trained on 630000 samples
# ✓ Predictions generated for 270000 test samples
# ✓ All results saved
#
# Files created:
#   • elasticnet_params.pkl
#   • elasticnet_history.csv
#   • elasticnet_study.pkl
#   • elasticnet_summary.pkl
#   • elasticnet_final_model.pkl
#   • elasticnet_coefficients.csv
#   • submission.csv
# ================================================================================
